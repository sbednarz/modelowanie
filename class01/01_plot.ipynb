# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 42)

f1 = 5 * np.sin(x)
f2 = 2 * np.sin(2*x)
f3 = 1 * np.sin(3*x)

plt.plot(x, f1)
plt.plot(x, f2, 'ro')
plt.plot(x, f3, 'g--')

# %%
x
# Out:
# array([ 0.        ,  0.15324842,  0.30649684,  0.45974527,  0.61299369,
#         0.76624211,  0.91949053,  1.07273895,  1.22598738,  1.3792358 ,
#         1.53248422,  1.68573264,  1.83898107,  1.99222949,  2.14547791,
#         2.29872633,  2.45197475,  2.60522318,  2.7584716 ,  2.91172002,
#         3.06496844,  3.21821686,  3.37146529,  3.52471371,  3.67796213,
#         3.83121055,  3.98445898,  4.1377074 ,  4.29095582,  4.44420424,
#         4.59745266,  4.75070109,  4.90394951,  5.05719793,  5.21044635,
#         5.36369477,  5.5169432 ,  5.67019162,  5.82344004,  5.97668846,
#         6.12993689,  6.28318531])

# %%
f1
# Out:
# array([  0.00000000e+00,   7.63246421e-01,   1.50860299e+00,
#          2.21859919e+00,   2.87659330e+00,   3.46716250e+00,
#          3.97646436e+00,   4.39256125e+00,   4.70570024e+00,
#          4.90854160e+00,   4.99633091e+00,   4.96701045e+00,
#          4.82126748e+00,   4.56251808e+00,   4.19682713e+00,
#          3.73276611e+00,   3.18121221e+00,   2.55509340e+00,
#          1.86908536e+00,   1.13926754e+00,   3.82746264e-01,
#         -3.82746264e-01,  -1.13926754e+00,  -1.86908536e+00,
#         -2.55509340e+00,  -3.18121221e+00,  -3.73276611e+00,
#         -4.19682713e+00,  -4.56251808e+00,  -4.82126748e+00,
#         -4.96701045e+00,  -4.99633091e+00,  -4.90854160e+00,
#         -4.70570024e+00,  -4.39256125e+00,  -3.97646436e+00,
#         -3.46716250e+00,  -2.87659330e+00,  -2.21859919e+00,
#         -1.50860299e+00,  -7.63246421e-01,  -1.22464680e-15])
